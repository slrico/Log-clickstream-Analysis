# %% [markdown]
# <a href="https://colab.research.google.com/github/unajmieh/Log-clickstream-Analysis/blob/main/windows_log_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

Maindata = pd.read_csv('./Windows_2k.log_structured.csv')

# Set pandas display options to show the full content of DataFrame columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)
Maindata = pd.read_csv('./Windows_2k.log_structured.csv')
Maindata.head()
# Out:
#    LineId        Date      Time Level Component  \
# 0       1  2016-09-28  04:30:30  Info       CBS
# 1       2  2016-09-28  04:30:31  Info       CSI
# 2       3  2016-09-28  04:30:31  Info       CSI
# 3       4  2016-09-28  04:30:31  Info       CSI
# 4       5  2016-09-28  04:30:31  Info       CBS
#
#                                                                                                                                                                         Content  \
# 0  Loaded Servicing Stack v6.1.7601.23505 with Core: C:\Windows\winsxs\amd64_microsoft-windows-servicingstack_31bf3856ad364e35_6.1.7601.23505_none_681aa442f6fed7f0\cbscore.dll
# 1       00000001@2016/9/27:20:30:31.455 WcpInitialize (wcp.dll version 0.0.0.6) called (stack @0x7fed806eb5d @0x7fef9fb9b6d @0x7fef9f8358f @0xff83e97c @0xff83d799 @0xff83db2f)
# 2    00000002@2016/9/27:20:30:31.458 WcpInitialize (wcp.dll version 0.0.0.6) called (stack @0x7fed806eb5d @0x7fefa006ade @0x7fef9fd2984 @0x7fef9f83665 @0xff83e97c @0xff83d799)
# 3       00000003@2016/9/27:20:30:31.458 WcpInitialize (wcp.dll version 0.0.0.6) called (stack @0x7fed806eb5d @0x7fefa1c8728 @0x7fefa1c8856 @0xff83e474 @0xff83d7de @0xff83db2f)
# 4                                                                                                                                       Ending TrustedInstaller initialization.
#
#   EventId  \
# 0     E23
# 1     E13
# 2     E13
# 3     E13
# 4     E17
#
#                                                                              EventTemplate
# 0                                    Loaded Servicing Stack <*> with Core: <*>\cbscore.dll
# 1  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize (wcp.dll version <*>) called (stack @<*>)
# 2  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize (wcp.dll version <*>) called (stack @<*>)
# 3  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize (wcp.dll version <*>) called (stack @<*>)
# 4                                                  Ending TrustedInstaller initialization.

# %%
import pandas as pd

# Load the dataset from the CSV file
Maindata = pd.read_csv('./Windows_2k.log_structured.csv')

# Set pandas display options
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', 100)  # Adjust the column width
pd.set_option('display.expand_frame_repr', False)  # Disable wrapping

# Display the DataFrame in a readable format
#print(Maindata.to_string(index=False))

# Convert to JSON format
json_data = Maindata.to_json(orient='records', lines=True)

# Save to file
# with open('output.json', 'w') as f:
#    f.write(json_data)

# print("Data has been converted to JSON format and saved as 'output.json'.")

# %%
from tabulate import tabulate

# Print using tabulate for better formatting
print(tabulate(Maindata, headers='keys', tablefmt='psql'))
# Out:
# +------+----------+------------+----------+---------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------+
# |      |   LineId | Date       | Time     | Level   | Component   | Content                                                                                                                                                                                                                                                                                                   | EventId   | EventTemplate                                                                                                                           |
# |------+----------+------------+----------+---------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------|
# |    0 |        1 | 2016-09-28 | 04:30:30 | Info    | CBS         | Loaded Servicing Stack v6.1.7601.23505 with Core: C:\Windows\winsxs\amd64_microsoft-windows-servicingstack_31bf3856ad364e35_6.1.7601.23505_none_681aa442f6fed7f0\cbscore.dll                                                                                                                              | E23       | Loaded Servicing Stack <*> with Core: <*>\cbscore.dll                                                                                   |
# |    1 |        2 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000001@2016/9/27:20:30:31.455 WcpInitialize (wcp.dll version 0.0.0.6) called (stack @0x7fed806eb5d @0x7fef9fb9b6d @0x7fef9f8358f @0xff83e97c @0xff83d799 @0xff83db2f)                                                                                                                                   | E13       | <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize (wcp.dll version <*>) called (stack @<*>)                                                 |
# |    2 |        3 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000002@2016/9/27:20:30:31.458 WcpInitialize (wcp.dll version 0.0.0.6) called (stack @0x7fed806eb5d @0x7fefa006ade @0x7fef9fd2984 @0x7fef9f83665 @0xff83e97c @0xff83d799)                                                                                                                                | E13       | <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize (wcp.dll version <*>) called (stack @<*>)                                                 |
# |    3 |        4 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000003@2016/9/27:20:30:31.458 WcpInitialize (wcp.dll version 0.0.0.6) called (stack @0x7fed806eb5d @0x7fefa1c8728 @0x7fefa1c8856 @0xff83e474 @0xff83d7de @0xff83db2f)                                                                                                                                   | E13       | <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize (wcp.dll version <*>) called (stack @<*>)                                                 |
# |    4 |        5 | 2016-09-28 | 04:30:31 | Info    | CBS         | Ending TrustedInstaller initialization.                                                                                                                                                                                                                                                                   | E17       | Ending TrustedInstaller initialization.                                                                                                 |
# |    5 |        6 | 2016-09-28 | 04:30:31 | Info    | CBS         | Starting the TrustedInstaller main loop.                                                                                                                                                                                                                                                                  | E44       | Starting the TrustedInstaller main loop.                                                                                                |
# |    6 |        7 | 2016-09-28 | 04:30:31 | Info    | CBS         | TrustedInstaller service starts successfully.                                                                                                                                                                                                                                                             | E48       | TrustedInstaller service starts successfully.                                                                                           |
# |    7 |        8 | 2016-09-28 | 04:30:31 | Info    | CBS         | SQM: Initializing online with Windows opt-in: False                                                                                                                                                                                                                                                       | E40       | SQM: Initializing online with Windows opt-in: False                                                                                     |
# |    8 |        9 | 2016-09-28 | 04:30:31 | Info    | CBS         | SQM: Cleaning up report files older than 10 days.                                                                                                                                                                                                                                                         | E37       | SQM: Cleaning up report files older than <*> days.                                                                                      |
# |    9 |       10 | 2016-09-28 | 04:30:31 | Info    | CBS         | SQM: Requesting upload of all unsent reports.                                                                                                                                                                                                                                                             | E42       | SQM: Requesting upload of all unsent reports.                                                                                           |
# |   10 |       11 | 2016-09-28 | 04:30:31 | Info    | CBS         | SQM: Failed to start upload with file pattern: C:\Windows\servicing\sqm\*_std.sqm, flags: 0x2 [HRESULT = 0x80004005 - E_FAIL]                                                                                                                                                                             | E39       | SQM: Failed to start upload with file pattern: <*>, flags: <*> [HRESULT = <*> - E_FAIL]                                                 |
# |   11 |       12 | 2016-09-28 | 04:30:31 | Info    | CBS         | SQM: Failed to start standard sample upload. [HRESULT = 0x80004005 - E_FAIL]                                                                                                                                                                                                                              | E38       | SQM: Failed to start standard sample upload. [HRESULT = <*> - E_FAIL]                                                                   |
# |   12 |       13 | 2016-09-28 | 04:30:31 | Info    | CBS         | SQM: Queued 0 file(s) for upload with pattern: C:\Windows\servicing\sqm\*_all.sqm, flags: 0x6                                                                                                                                                                                                             | E41       | SQM: Queued <*> file(s) for upload with pattern: <*>, flags: <*>                                                                        |
# |   13 |       14 | 2016-09-28 | 04:30:31 | Info    | CBS         | SQM: Warning: Failed to upload all unsent reports. [HRESULT = 0x80004005 - E_FAIL]                                                                                                                                                                                                                        | E43       | SQM: Warning: Failed to upload all unsent reports. [HRESULT = <*> - E_FAIL]                                                             |
# |   14 |       15 | 2016-09-28 | 04:30:31 | Info    | CBS         | No startup processing required, TrustedInstaller service was not set as autostart, or else a reboot is still pending.                                                                                                                                                                                     | E25       | No startup processing required, TrustedInstaller service was not set as autostart, or else a reboot is still pending.                   |
# |   15 |       16 | 2016-09-28 | 04:30:31 | Info    | CBS         | NonStart: Checking to ensure startup processing was not required.                                                                                                                                                                                                                                         | E26       | NonStart: Checking to ensure startup processing was not required.                                                                       |
# |   16 |       17 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000004 IAdvancedInstallerAwareStore_ResolvePendingTransactions (call 1) (flags = 00000004, progress = NULL, phase = 0, pdwDisposition = @0xb6fd90                                                                                                                                                       | E5        | <*> IAdvancedInstallerAwareStore_ResolvePendingTransactions (call <*>) (flags = <*>, progress = <*>, phase = <*>, pdwDisposition = @<*> |
# |   17 |       18 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000005 Creating NT transaction (seq 1), objectname [6]"(null)"                                                                                                                                                                                                                                          | E2        | <*> Creating NT transaction (seq <*>), objectname [<*>]"(null)"                                                                         |
# |   18 |       19 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000006 Created NT transaction (seq 1) result 0x00000000, handle @0x214                                                                                                                                                                                                                                  | E1        | <*> Created NT transaction (seq <*>) result <*>, handle @<*>                                                                            |
# |   19 |       20 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000007@2016/9/27:20:30:31.462 CSI perf trace:                                                                                                                                                                                                                                                           | E3        | <*> CSI perf trace:                                                                                                                     |
# |   20 |       21 | 2016-09-28 | 04:30:31 | Info    | CBS         | NonStart: Success, startup processing not required as expected.                                                                                                                                                                                                                                           | E27       | NonStart: Success, startup processing not required as expected.                                                                         |
# |   21 |       22 | 2016-09-28 | 04:30:31 | Info    | CBS         | Startup processing thread terminated normally                                                                                                                                                                                                                                                             | E47       | Startup processing thread terminated normally                                                                                           |
# |   22 |       23 | 2016-09-28 | 04:30:31 | Info    | CSI         | 00000008 CSI Store 4991456 (0x00000000004c29e0) initialized                                                                                                                                                                                                                                               | E4        | <*> CSI Store <*> (<*>) initialized                                                                                                     |
# |   23 |       24 | 2016-09-28 | 04:30:31 | Info    | CBS         | Session: 30546173_4261722401 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# |   24 |       25 | 2016-09-28 | 04:30:31 | Info    | CBS         | Session: 30546173_4262462443 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# |   25 |       26 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   26 |       27 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   27 |       28 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   28 |       29 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   29 |       30 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   30 |       31 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   31 |       32 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   32 |       33 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   33 |       34 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   34 |       35 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   35 |       36 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   36 |       37 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   37 |       38 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   38 |       39 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   39 |       40 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   40 |       41 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   41 |       42 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   42 |       43 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   43 |       44 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   44 |       45 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   45 |       46 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   46 |       47 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   47 |       48 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   48 |       49 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   49 |       50 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   50 |       51 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   51 |       52 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   52 |       53 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   53 |       54 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   54 |       55 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   55 |       56 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   56 |       57 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   57 |       58 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   58 |       59 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   59 |       60 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   60 |       61 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   61 |       62 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   62 |       63 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   63 |       64 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   64 |       65 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   65 |       66 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   66 |       67 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   67 |       68 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   68 |       69 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   69 |       70 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   70 |       71 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   71 |       72 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   72 |       73 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   73 |       74 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   74 |       75 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   75 |       76 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   76 |       77 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   77 |       78 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   78 |       79 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   79 |       80 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   80 |       81 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   81 |       82 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   82 |       83 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   83 |       84 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   84 |       85 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   85 |       86 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# |   86 |       87 | 2016-09-28 | 04:30:31 | Info    | CBS         | Warning: Unrecognized packageExtended attribute.                                                                                                                                                                                                                                                          | E50       | Warning: Unrecognized packageExtended attribute.                                                                                        |
# |   87 |       88 | 2016-09-28 | 04:30:31 | Info    | CBS         | Expecting attribute name [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                             | E18       | Expecting attribute name [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                  |
# |   88 |       89 | 2016-09-28 | 04:30:31 | Info    | CBS         | Failed to get next element [HRESULT = 0x800f080d - CBS_E_MANIFEST_INVALID_ITEM]                                                                                                                                                                                                                           | E20       | Failed to get next element [HRESULT = <*> - CBS_E_MANIFEST_INVALID_ITEM]                                                                |
# ...
# | 1971 |     1972 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3351103853 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1972 |     1973 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2654428~31bf3856ad364e35~amd64~~6.1.1.0, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1973 |     1974 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3351293864 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1974 |     1975 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB3004361~31bf3856ad364e35~amd64~~6.1.1.0, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1975 |     1976 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3351423871 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1976 |     1977 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB3108371~31bf3856ad364e35~amd64~~6.1.1.0, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1977 |     1978 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3351723888 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1978 |     1979 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2892074~31bf3856ad364e35~amd64~~6.1.1.0, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1979 |     1980 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3352763948 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1980 |     1981 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2973351~31bf3856ad364e35~amd64~~6.1.1.1, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1981 |     1982 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3355304093 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1982 |     1983 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2729094~31bf3856ad364e35~amd64~~6.1.2.0, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1983 |     1984 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3355724117 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1984 |     1985 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2511455~31bf3856ad364e35~amd64~~6.1.1.0, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1985 |     1986 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3355864125 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1986 |     1987 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2564958~31bf3856ad364e35~amd64~~6.1.1.1, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1987 |     1988 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3356114139 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1988 |     1989 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB3045685~31bf3856ad364e35~amd64~~6.1.1.0, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1989 |     1990 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3356384155 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1990 |     1991 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2836943~31bf3856ad364e35~amd64~~6.1.2.0, ApplicableState: 80, CurrentState:112                                                                                                                                                           | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1991 |     1992 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3356844181 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1992 |     1993 | 2016-09-29 | 02:04:39 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2698365~31bf3856ad364e35~amd64~~6.1.1.2, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1993 |     1994 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3357084195 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1994 |     1995 | 2016-09-29 | 02:04:39 | Info    | CBS         | Session: 30546354_3357894241 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1995 |     1996 | 2016-09-29 | 02:04:40 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB3031432~31bf3856ad364e35~amd64~~6.1.1.0, ApplicableState: 80, CurrentState:112                                                                                                                                                           | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1996 |     1997 | 2016-09-29 | 02:04:40 | Info    | CBS         | Session: 30546354_3360174372 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1997 |     1998 | 2016-09-29 | 02:04:40 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB3004375~31bf3856ad364e35~amd64~~6.1.3.1, ApplicableState: 112, CurrentState:112                                                                                                                                                          | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# | 1998 |     1999 | 2016-09-29 | 02:04:40 | Info    | CBS         | Session: 30546354_3363894584 initialized by client WindowsUpdateAgent.                                                                                                                                                                                                                                    | E36       | Session: <*>_<*> initialized by client WindowsUpdateAgent.                                                                              |
# | 1999 |     2000 | 2016-09-29 | 02:04:40 | Info    | CBS         | Read out cached package applicability for package: Package_for_KB2928120~31bf3856ad364e35~amd64~~6.1.1.2, ApplicableState: 0, CurrentState:0                                                                                                                                                              | E29       | Read out cached package applicability for package: <*>, ApplicableState: <*>, CurrentState:<*>                                          |
# +------+----------+------------+----------+---------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------+

# %%
print(Maindata.describe(include='all'))  # Summary for all columns
# Out:
#              LineId        Date      Time Level Component                                           Content EventId                                               EventTemplate
# count   2000.000000        2000      2000  2000      2000                                              2000    2000                                                        2000
# unique          NaN           2        76     1         2                                               963      50                                                          50
# top             NaN  2016-09-29  02:03:48  Info       CBS  Warning: Unrecognized packageExtended attribute.     E36  Session: <*>_<*> initialized by client WindowsUpdateAgent.
# freq            NaN        1047       210  2000      1973                                               280     608                                                         608
# mean    1000.500000         NaN       NaN   NaN       NaN                                               NaN     NaN                                                         NaN
# std      577.494589         NaN       NaN   NaN       NaN                                               NaN     NaN                                                         NaN
# min        1.000000         NaN       NaN   NaN       NaN                                               NaN     NaN                                                         NaN
# 25%      500.750000         NaN       NaN   NaN       NaN                                               NaN     NaN                                                         NaN
# 50%     1000.500000         NaN       NaN   NaN       NaN                                               NaN     NaN                                                         NaN
# 75%     1500.250000         NaN       NaN   NaN       NaN                                               NaN     NaN                                                         NaN
# max     2000.000000         NaN       NaN   NaN       NaN                                               NaN     NaN                                                         NaN
